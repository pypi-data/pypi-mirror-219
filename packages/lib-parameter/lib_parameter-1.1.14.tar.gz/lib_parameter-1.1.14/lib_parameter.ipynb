# %%
# update pip and setuptools
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools
# Out:
# Requirement already up-to-date: pip in /srv/conda/envs/notebook/lib/python3.7/site-packages (20.1.1)
# Requirement already up-to-date: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (49.1.0)

# %%
# install lib_parameter
# !{sys.executable} -m pip install lib_parameter
# Out:
# Requirement already satisfied: lib_parameter in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.0.3)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.7/site-packages (from lib_parameter) (7.1.2)
# Requirement already satisfied: typing in /srv/conda/envs/notebook/lib/python3.7/site-packages (from lib_parameter) (3.7.4.1)
# Requirement already satisfied: pathlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from lib_parameter) (1.0.1)

# %%
# easy example
import lib_parameter
x=None
y=lib_parameter.get_default_if_none(parameter=x, default=5)
print(y)
# Out:
# 5

# %%
# useful example
import lib_parameter
from typing import List, Optional

def test(x: Optional[List[str]] = None) -> str:
    y = lib_parameter.get_default_if_none(parameter=x, default=['something'])
    return '-'.join(y)

test()
# Out:
# 'something'
